# %% [markdown]
# <a href="https://colab.research.google.com/github/ntnmj7/Conectar_Dataset_Kaggle/blob/main/Obtener_Datasets_de_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos las librerías necesarias

import json
with open("/root/.kaggle/kaggle.json", "w") as file:
  json.dump(api_token, file)
import zipfile
import pandas as pd

# %%
#Obtenemos un api general desde el apartado de "Account" en Kaggle

api_token = {
    "username":"luanme",
    "key":"3540cb054a267bc4b4aa34ea5bf1d83f"
    }

# %%
#Eliminamos el directorio o archivo en caso de que exista

# !rm -rf /root/.kaggle.

# %%
#Creamos el directorio

# !mkdir /root/.kaggle

# %%
#Exploramos los datasets disponibleas por medio de está forma

# !kaggle datasets list
# Out:
# ref                                                                  title                                             size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------------  -----------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# teocalvo/teomewhy-loyalty-system                                     TeoMeWhy Loyalty System                           23MB  2024-06-19 11:52:24            229        397  1.0
# shreyanshverma27/online-sales-dataset-popular-marketplace-data       Online Sales Dataset - Popular Marketplace Data    7KB  2024-05-25 23:55:26           8961        163  1.0
# nelgiriyewithana/most-streamed-spotify-songs-2024                    Most Streamed Spotify Songs 2024                 496KB  2024-06-15 18:50:51           1059         27  1.0
# ...

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
#Descargamos el Dataset poniendo el nombre ref

# !kaggle datasets download -d zeesolver/data-eng-salary-2024
# Out:
# Dataset URL: https://www.kaggle.com/datasets/zeesolver/data-eng-salary-2024
# License(s): Apache 2.0
# ...
#   0% 0.00/108k [00:00<?, ?B/s]
# 100% 108k/108k [00:00<00:00, 52.1MB/s]

# %%
#Obtenemos los archivos en el archivo zip

archivo_zip = "/content/data-eng-salary-2024.zip"
with zipfile.ZipFile(archivo_zip, "r") as zip_file:
  for nombre_archivo in zip_file.namelist():
    print(nombre_archivo)
# Out:
# Dataset salary 2024.csv

# %%
#Leemos el archivo

df = pd.read_csv("/content/data-eng-salary-2024.zip")
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %%
#A través de esta forma podemos descargar el recurso de cualquier dataset de kaggle

# !kaggle datasets download -d mohamedhamad21/spotify-tracks-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mohamedhamad21/spotify-tracks-dataset
# License(s): Apache 2.0
# ...
#   0% 0.00/8.17M [00:00<?, ?B/s]
# 100% 8.17M/8.17M [00:00<00:00, 93.6MB/s]

# %%
#Obtenemos los archivos en el archivo zip

archivo_zip = "/content/spotify-tracks-dataset.zip"
with zipfile.ZipFile(archivo_zip, "r") as zip_file:
  for nombre_archivo in zip_file.namelist():
    print(nombre_archivo)
# Out:
# dataset.csv

# %%
#Obtenemos un archivo específico en el archivo zip

nombre_archivo1 = "dataset.csv"

with zipfile.ZipFile(archivo_zip, "r") as zip_file:
  with zip_file.open(nombre_archivo1) as spotify:
    dataframe_spotify = pd.read_csv(spotify)

# %%
#Leemos el archivo

dataframe_spotify.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...
